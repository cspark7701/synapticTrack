# %%
import numpy as np

# %%
exp_centroid_x = np.zeros((4, 5, 3), dtype=float)
exp_centroid_y = np.zeros((4, 5, 3), dtype=float)

# %%
#stm0, 1.1 mrad kick
exp_centroid_x[0,0,0] = 0.521
exp_centroid_x[1,0,0] = -1.735
exp_centroid_x[2,0,0] = 2.349
exp_centroid_x[3,0,0] = 2.712

exp_centroid_y[0,0,0] = 0.815
exp_centroid_y[1,0,0] = -0.601
exp_centroid_y[2,0,0] = 1.185
exp_centroid_y[3,0,0] = -1.764

#stm0, -1.1 mrad kick
exp_centroid_x[0,0,1] = -0.149
exp_centroid_x[1,0,1] = -1.382
exp_centroid_x[2,0,1] = 1.352
exp_centroid_x[3,0,1] = 1.061

exp_centroid_y[0,0,1] = 0.108
exp_centroid_y[1,0,1] = 1.500
exp_centroid_y[2,0,1] = 0.335
exp_centroid_y[3,0,1] = -4.023

#stm0, 0.0 mrad kick
exp_centroid_x[0,0,2] = 0.3090137816751236
exp_centroid_x[1,0,2] = -0.9824557871403435
exp_centroid_x[2,0,2] = 0.7298309740340578
exp_centroid_x[3,0,2] = 0.029857274496016818

exp_centroid_y[0,0,2] = 1.0616893745244138
exp_centroid_y[1,0,2] = 0.37908752856629696
exp_centroid_y[2,0,2] = 0.5854858780835129
exp_centroid_y[3,0,2] = -2.737536811230646

# %%
#stm1, 1.1 mrad kick
exp_centroid_x[0,1,0] = 0.000
exp_centroid_x[1,1,0] = -2.940
exp_centroid_x[2,1,0] = 2.973
exp_centroid_x[3,1,0] = 4.902

exp_centroid_y[0,1,0] = 0.000
exp_centroid_y[1,1,0] = -0.420
exp_centroid_y[2,1,0] = 0.824
exp_centroid_y[3,1,0] = -1.405

#stm1, -1.1 mrad kick
exp_centroid_x[0,1,1] = 0.000
exp_centroid_x[1,1,1] = -0.348
exp_centroid_x[2,1,1] = 0.823
exp_centroid_x[3,1,1] = -0.493

exp_centroid_y[0,1,1] = 0.000
exp_centroid_y[1,1,1] = 1.569
exp_centroid_y[2,1,1] = 0.711
exp_centroid_y[3,1,1] = -4.843

#stm1, 0.0 mrad kick
exp_centroid_x[0,1,2] = 0.3090137816751236
exp_centroid_x[1,1,2] = -0.9824557871403435
exp_centroid_x[2,1,2] = 0.7298309740340578
exp_centroid_x[3,1,2] = 0.029857274496016818

exp_centroid_y[0,1,2] = 1.0616893745244138
exp_centroid_y[1,1,2] = 0.37908752856629696
exp_centroid_y[2,1,2] = 0.5854858780835129
exp_centroid_y[3,1,2] = -2.737536811230646

# %%
#stm2, 1.1 mrad kick
exp_centroid_x[0,2,0] = 0.000
exp_centroid_x[1,2,0] = -1.841
exp_centroid_x[2,2,0] = 1.431
exp_centroid_x[3,2,0] = 1.757

exp_centroid_y[0,2,0] = 0.000
exp_centroid_y[1,2,0] = 1.828
exp_centroid_y[2,2,0] = -0.184
exp_centroid_y[3,2,0] = -3.611

#stm2, -1.1 mrad kick
exp_centroid_x[0,2,1] = 0.000
exp_centroid_x[1,2,1] = -1.542
exp_centroid_x[2,2,1] = 2.424
exp_centroid_x[3,2,1] = 2.700

exp_centroid_y[0,2,1] = 0.000
exp_centroid_y[1,2,1] = -0.535
exp_centroid_y[2,2,1] = 1.534
exp_centroid_y[3,2,1] = -2.305

#stm2, 0.0 mrad kick
exp_centroid_x[0,2,2] = 0.3090137816751236
exp_centroid_x[1,2,2] = -0.9824557871403435
exp_centroid_x[2,2,2] = 0.7298309740340578
exp_centroid_x[3,2,2] = 0.029857274496016818

exp_centroid_y[0,2,2] = 1.0616893745244138
exp_centroid_y[1,2,2] = 0.37908752856629696
exp_centroid_y[2,2,2] = 0.5854858780835129
exp_centroid_y[3,2,2] = -2.737536811230646

# %%
#stm3, 1.1 mrad kick
exp_centroid_x[0,3,0] = 0.000
exp_centroid_x[1,3,0] = -1.177
exp_centroid_x[2,3,0] = 1.590
exp_centroid_x[3,3,0] = 1.490

exp_centroid_y[0,3,0] = 0.000
exp_centroid_y[1,3,0] = 1.220
exp_centroid_y[2,3,0] = 0.721
exp_centroid_y[3,3,0] = -4.317

#stm3, -1.1 mrad kick
exp_centroid_x[0,3,1] = 0.000
exp_centroid_x[1,3,1] = -2.202
exp_centroid_x[2,3,1] = 2.218
exp_centroid_x[3,3,1] = 3.120

exp_centroid_y[0,3,1] = 0.000
exp_centroid_y[1,3,1] = -0.393
exp_centroid_y[2,3,1] = 0.956
exp_centroid_y[3,3,1] = -1.709

#stm3, 0.0 mrad kick
exp_centroid_x[0,3,2] = 0.3090137816751236
exp_centroid_x[1,3,2] = -0.9824557871403435
exp_centroid_x[2,3,2] = 0.7298309740340578
exp_centroid_x[3,3,2] = 0.029857274496016818

exp_centroid_y[0,3,2] = 1.0616893745244138
exp_centroid_y[1,3,2] = 0.37908752856629696
exp_centroid_y[2,3,2] = 0.5854858780835129
exp_centroid_y[3,3,2] = -2.737536811230646

# %%
#stm4, 1.1 mrad kick
exp_centroid_x[0,4,0] = 0.000
exp_centroid_x[1,4,0] = 0.000
exp_centroid_x[2,4,0] = 2.587
exp_centroid_x[3,4,0] = 3.500

exp_centroid_y[0,4,0] = 0.000
exp_centroid_y[1,4,0] = 0.000
exp_centroid_y[2,4,0] = 1.600
exp_centroid_y[3,4,0] = -1.413

#stm4, -1.1 mrad kick
exp_centroid_x[0,4,1] = 0.000
exp_centroid_x[1,4,1] = 0.000
exp_centroid_x[2,4,1] = 1.155
exp_centroid_x[3,4,1] = 0.636

exp_centroid_y[0,4,1] = 0.000
exp_centroid_y[1,4,1] = 0.000
exp_centroid_y[2,4,1] = -0.142
exp_centroid_y[3,4,1] = -4.695

#stm4, 0.0 mrad kick
exp_centroid_x[0,4,2] = 0.3090137816751236
exp_centroid_x[1,4,2] = -0.9824557871403435
exp_centroid_x[2,4,2] = 0.7298309740340578
exp_centroid_x[3,4,2] = 0.029857274496016818

exp_centroid_y[0,4,2] = 1.0616893745244138
exp_centroid_y[1,4,2] = 0.37908752856629696
exp_centroid_y[2,4,2] = 0.5854858780835129
exp_centroid_y[3,4,2] = -2.737536811230646

# %%
np.save("exp_centroid_x.npy", exp_centroid_x)
np.save("exp_centroid_y.npy", exp_centroid_y)
